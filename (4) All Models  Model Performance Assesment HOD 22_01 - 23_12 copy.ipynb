# %%
from Functions_3 import *

# %%
import pickle

from Functions_3 import *

for i in range(6):        
    with open(f'Model Performance Data HOD 21_01 - 22_12/ALL_models_results_across_realization_{i+1}.pkl' , 'rb') as f:
        data = pickle.load(f)

        plot_model_six_bars(
            data,
            title="Metrics per Model Criteria Set " + str(i+1),
            annotate=True,
            annotate_position="below",   
            xtick_rotation=45,
            save_path=None               
        )

# %%
import pickle

from Functions_3 import *

for i in range(6):        
    with open(f'Model Performance Data HOD 21_01 - 22_12 Sev Loss/ALL_models_results_across_realization_{i+1}.pkl' , 'rb') as f:
        data = pickle.load(f)

        plot_model_six_bars(
            data,
            title="Metrics per Model Criteria Set " + str(i+1),
            annotate=True,
            annotate_position="below",   
            xtick_rotation=45,
            save_path=None               
        )
